# %%
import pandas as pd
import numpy as np

# %%
# Load dataframe
exp = pd.read_csv('data/processed/updated_dataset.csv')
exp
# Out:
#      Unique.ID                 Grantor          Grantee            Program  \
# 0          NaN  City of Imperial Beach              NaN                NaN
# 1          NaN  City of Imperial Beach              NaN                NaN
# 2          NaN  City of Imperial Beach              NaN                NaN
# 3          NaN  City of Imperial Beach              NaN                NaN
# 4          NaN  City of Imperial Beach              NaN                NaN
# ...        ...                     ...              ...                ...
# 2026      1066     City of Chula Vista  ONE TIME VENDOR      motel voucher
# 2027       NaN     City of Chula Vista     KIKU GARDENS  rental assistance
# 2028       NaN     City of Chula Vista     KIKU GARDENS  rental assistance
# 2029       NaN     City of Chula Vista     KIKU GARDENS  rental assistance
# 2030       NaN     City of Chula Vista      MARK II, LP  rental assistance
#
#         Year        Date EndDate      Amount AmendmentNumber  \
# 0     2022.0         NaN     NaN           0             NaN
# 1     2021.0         NaN     NaN           0             NaN
# 2     2020.0         NaN     NaN           0             NaN
# 3     2019.0         NaN     NaN           0             NaN
# 4     2018.0         NaN     NaN           0             NaN
# ...      ...         ...     ...         ...             ...
# 2026  2021.0  12/23/2021     NaN    $560.30              NaN
# 2027  2021.0  12/28/2021     NaN    $212.00              NaN
# 2028  2021.0  12/28/2021     NaN    $212.00              NaN
# 2029  2021.0  12/28/2021     NaN    $212.00              NaN
# 2030  2021.0  12/28/2021     NaN  $1,668.00              NaN
#
#          Funding.Agency  ... Issued Funding.Type Years Average.By.Year  \
# 0                   NaN  ...    NaN          NaN   NaN             NaN
# 1                   NaN  ...    NaN          NaN   NaN             NaN
# 2                   NaN  ...    NaN          NaN   NaN             NaN
# 3                   NaN  ...    NaN          NaN   NaN             NaN
# 4                   NaN  ...    NaN          NaN   NaN             NaN
# ...                 ...  ...    ...          ...   ...             ...
# 2026               CDBG  ...    NaN          NaN   NaN             NaN
# 2027               HOME  ...    NaN          NaN   NaN             NaN
# 2028               HOME  ...    NaN          NaN   NaN             NaN
# 2029               HOME  ...    NaN          NaN   NaN             NaN
# 2030  Housing Authority  ...    NaN          NaN   NaN             NaN
#
#                         City.Year  Population Amount.Per.Capita  \
# 0     City of Imperial Beach|2022         NaN            $0.00
# 1     City of Imperial Beach|2021         NaN            $0.00
# 2     City of Imperial Beach|2020         NaN            $0.00
# 3     City of Imperial Beach|2019         NaN            $0.00
# 4     City of Imperial Beach|2018         NaN            $0.00
# ...                           ...         ...               ...
# 2026                          NaN         NaN               NaN
# 2027                          NaN         NaN               NaN
# 2028                          NaN         NaN               NaN
# 2029                          NaN         NaN               NaN
# 2030                          NaN         NaN               NaN
#
#      Amount.Per.PEH  Population.PEH    ExpenditureType
# 0            $0.00              0.0      Other/Unknown
# 1            $0.00              0.0      Other/Unknown
# 2            $0.00             16.0      Other/Unknown
# 3            $0.00             12.0      Other/Unknown
# 4            $0.00              7.0      Other/Unknown
# ...             ...             ...                ...
# 2026            NaN             NaN  Crisis Management
# 2027            NaN             NaN         Prevention
# 2028            NaN             NaN         Prevention
# 2029            NaN             NaN         Prevention
# 2030            NaN             NaN         Prevention
#
# [2031 rows x 23 columns]

# %%
# Remove NAs in the Date column
exp = exp[exp['Date'].notna()]
exp
# Out:
#      Unique.ID              Grantor                     Grantee  \
# 8          NaN  City of Chula Vista            SBCS CORPORATION
# 9          NaN  City of Chula Vista            SBCS CORPORATION
# 10         NaN  City of Chula Vista            SBCS CORPORATION
# 11        1068  City of Chula Vista            SBCS CORPORATION
# 12        1067  City of Chula Vista  INTERFAITH SHELTER NETWORK
# ...        ...                  ...                         ...
# 2026      1066  City of Chula Vista             ONE TIME VENDOR
# 2027       NaN  City of Chula Vista                KIKU GARDENS
# 2028       NaN  City of Chula Vista                KIKU GARDENS
# 2029       NaN  City of Chula Vista                KIKU GARDENS
# 2030       NaN  City of Chula Vista                 MARK II, LP
#
#                 Program    Year        Date EndDate       Amount  \
# 8     rental assistance  2017.0  10/23/2017     NaN  $14,142.74
# 9     rental assistance  2017.0  10/23/2017     NaN  $12,931.10
# 10    rental assistance  2017.0  10/23/2017     NaN  $10,285.61
# 11    homeless services  2017.0   11/7/2017     NaN     $276.00
# 12              shelter  2017.0   11/8/2017     NaN   $1,971.50
# ...                 ...     ...         ...     ...          ...
# 2026      motel voucher  2021.0  12/23/2021     NaN     $560.30
# 2027  rental assistance  2021.0  12/28/2021     NaN     $212.00
# 2028  rental assistance  2021.0  12/28/2021     NaN     $212.00
# 2029  rental assistance  2021.0  12/28/2021     NaN     $212.00
# 2030  rental assistance  2021.0  12/28/2021     NaN   $1,668.00
#
#      AmendmentNumber     Funding.Agency  ... Issued Funding.Type Years  \
# 8                NaN                NaN  ...    NaN          NaN   NaN
# 9                NaN                NaN  ...    NaN          NaN   NaN
# 10               NaN                NaN  ...    NaN          NaN   NaN
# 11               NaN                NaN  ...    NaN          NaN   NaN
# 12               NaN                NaN  ...    NaN          NaN   NaN
# ...              ...                ...  ...    ...          ...   ...
# 2026             NaN               CDBG  ...    NaN          NaN   NaN
# 2027             NaN               HOME  ...    NaN          NaN   NaN
# 2028             NaN               HOME  ...    NaN          NaN   NaN
# 2029             NaN               HOME  ...    NaN          NaN   NaN
# 2030             NaN  Housing Authority  ...    NaN          NaN   NaN
#
#      Average.By.Year                 City.Year  Population Amount.Per.Capita  \
# 8                NaN  City of Chula Vista|2017    266427.0            $0.05
# 9                NaN  City of Chula Vista|2017    266427.0            $0.05
# 10               NaN  City of Chula Vista|2017    266427.0            $0.04
# 11               NaN  City of Chula Vista|2017    266427.0            $0.00
# 12               NaN  City of Chula Vista|2017    266427.0            $0.01
# ...              ...                       ...         ...               ...
# 2026             NaN                       NaN         NaN               NaN
# 2027             NaN                       NaN         NaN               NaN
# 2028             NaN                       NaN         NaN               NaN
# 2029             NaN                       NaN         NaN               NaN
# 2030             NaN                       NaN         NaN               NaN
#
#      Amount.Per.PEH  Population.PEH    ExpenditureType
# 8           $38.54            367.0         Prevention
# 9           $35.23            367.0         Prevention
# 10          $28.03            367.0         Prevention
# 11           $0.75            367.0  Crisis Management
# 12           $5.37            367.0  Crisis Management
# ...             ...             ...                ...
# 2026            NaN             NaN  Crisis Management
# 2027            NaN             NaN         Prevention
# 2028            NaN             NaN         Prevention
# 2029            NaN             NaN         Prevention
# 2030            NaN             NaN         Prevention
#
# [1204 rows x 23 columns]

# %%
exp.columns
# Out:
# Index(['Unique.ID', 'Grantor', 'Grantee', 'Program', 'Year', 'Date', 'EndDate',
#        'Amount', 'AmendmentNumber', 'Funding.Agency', 'Funding.Source',
#        'Category', 'Location', 'Issued', 'Funding.Type', 'Years',
#        'Average.By.Year', 'City.Year', 'Population', 'Amount.Per.Capita',
#        'Amount.Per.PEH', 'Population.PEH', 'ExpenditureType'],
#       dtype='object')

# %%
columns_to_drop = ['Unique.ID', 'EndDate', 'AmendmentNumber', 'Funding.Agency', 'Funding.Source',
       'Category', 'Location', 'Issued', 'Funding.Type', 'Years',
       'Average.By.Year', 'City.Year', 'Population', 'Amount.Per.Capita',
       'Amount.Per.PEH', 'Population.PEH']
exp = exp.drop(columns=columns_to_drop)
exp
# Out:
#                   Grantor                     Grantee            Program  \
# 8     City of Chula Vista            SBCS CORPORATION  rental assistance
# 9     City of Chula Vista            SBCS CORPORATION  rental assistance
# 10    City of Chula Vista            SBCS CORPORATION  rental assistance
# 11    City of Chula Vista            SBCS CORPORATION  homeless services
# 12    City of Chula Vista  INTERFAITH SHELTER NETWORK            shelter
# ...                   ...                         ...                ...
# 2026  City of Chula Vista             ONE TIME VENDOR      motel voucher
# 2027  City of Chula Vista                KIKU GARDENS  rental assistance
# 2028  City of Chula Vista                KIKU GARDENS  rental assistance
# 2029  City of Chula Vista                KIKU GARDENS  rental assistance
# 2030  City of Chula Vista                 MARK II, LP  rental assistance
#
#         Year        Date       Amount    ExpenditureType
# 8     2017.0  10/23/2017  $14,142.74          Prevention
# 9     2017.0  10/23/2017  $12,931.10          Prevention
# 10    2017.0  10/23/2017  $10,285.61          Prevention
# 11    2017.0   11/7/2017     $276.00   Crisis Management
# 12    2017.0   11/8/2017   $1,971.50   Crisis Management
# ...      ...         ...          ...                ...
# 2026  2021.0  12/23/2021     $560.30   Crisis Management
# 2027  2021.0  12/28/2021     $212.00          Prevention
# 2028  2021.0  12/28/2021     $212.00          Prevention
# 2029  2021.0  12/28/2021     $212.00          Prevention
# 2030  2021.0  12/28/2021   $1,668.00          Prevention
#
# [1204 rows x 7 columns]

# %%
# Rename the columns
exp = exp.rename(columns={
    'Grantor': 'city', 
    'Grantee': 'grantee', 
    'Program': 'program', 
    'Year': 'year', 
    'Date': 'date', 
    'Amount': 'amount', 
    'ExpenditureType': 'exp_type'
})

# Try converting the 'date' column to datetime, allowing for mixed formats and coercing errors
exp['date'] = pd.to_datetime(exp['date'], format='mixed', errors='coerce')

# Check if any rows have invalid dates (i.e., rows where 'date' is NaT after coercion)
invalid_dates = exp[exp['date'].isna()]

# Add the "month" column with month names in word form
exp['month'] = exp['date'].dt.strftime('%B')

# %%
exp['program'].unique()
# Out:
# array(['rental assistance', 'homeless services', 'shelter',
#        'motel voucher', 'rapid re housing', 'project h.o.p.e.',
#        'take back the streets', 'work for hope',
#        'housing navigation services', 'railing/fencing improvements',
#        'facility improvement', 'housing assistance', 'outreach',
#        'family reunification program',
#        'general funding for homelessness services',
#        'housing stability services', '211 assistance', 'case management',
#        'flexible funds', 'point in time count',
#        'consulting services homeless', 'communities in action',
#        'legal services solutions for change',
#        'translation homeless plan mtg', 'cdbg consolidated plan consult',
#        'plha plan 7699835', 'homelessness prevention',
#        'bridge to housing program', 'homeshare program',
#        'homelessness educational initiatives',
#        'training/technical assistance', 'restrooms', 'service center',
#        'neighborhood revitalization services', 'employment/benefits', nan,
#        'temporary housing and services', 'food and nutrition',
#        'emergency stabalization and supportive services', 'call center',
#        'safe parking', 'transitional storage', 'opening doors program',
#        'bridge to housing network',
#        'transitional housing and supportive services',
#        'contract sobering services', 'interim housing facility'],
#       dtype=object)

# %%
cleanexp = pd.read_csv('data/processed/updated_dataset.csv')
cleanexp
# Out:
#      Unique.ID                 Grantor          Grantee            Program  \
# 0          NaN  City of Imperial Beach              NaN                NaN
# 1          NaN  City of Imperial Beach              NaN                NaN
# 2          NaN  City of Imperial Beach              NaN                NaN
# 3          NaN  City of Imperial Beach              NaN                NaN
# 4          NaN  City of Imperial Beach              NaN                NaN
# ...        ...                     ...              ...                ...
# 2026      1066     City of Chula Vista  ONE TIME VENDOR      motel voucher
# 2027       NaN     City of Chula Vista     KIKU GARDENS  rental assistance
# 2028       NaN     City of Chula Vista     KIKU GARDENS  rental assistance
# 2029       NaN     City of Chula Vista     KIKU GARDENS  rental assistance
# 2030       NaN     City of Chula Vista      MARK II, LP  rental assistance
#
#         Year        Date EndDate      Amount AmendmentNumber  \
# 0     2022.0         NaN     NaN           0             NaN
# 1     2021.0         NaN     NaN           0             NaN
# 2     2020.0         NaN     NaN           0             NaN
# 3     2019.0         NaN     NaN           0             NaN
# 4     2018.0         NaN     NaN           0             NaN
# ...      ...         ...     ...         ...             ...
# 2026  2021.0  12/23/2021     NaN    $560.30              NaN
# 2027  2021.0  12/28/2021     NaN    $212.00              NaN
# 2028  2021.0  12/28/2021     NaN    $212.00              NaN
# 2029  2021.0  12/28/2021     NaN    $212.00              NaN
# 2030  2021.0  12/28/2021     NaN  $1,668.00              NaN
#
#          Funding.Agency  ... Issued Funding.Type Years Average.By.Year  \
# 0                   NaN  ...    NaN          NaN   NaN             NaN
# 1                   NaN  ...    NaN          NaN   NaN             NaN
# 2                   NaN  ...    NaN          NaN   NaN             NaN
# 3                   NaN  ...    NaN          NaN   NaN             NaN
# 4                   NaN  ...    NaN          NaN   NaN             NaN
# ...                 ...  ...    ...          ...   ...             ...
# 2026               CDBG  ...    NaN          NaN   NaN             NaN
# 2027               HOME  ...    NaN          NaN   NaN             NaN
# 2028               HOME  ...    NaN          NaN   NaN             NaN
# 2029               HOME  ...    NaN          NaN   NaN             NaN
# 2030  Housing Authority  ...    NaN          NaN   NaN             NaN
#
#                         City.Year  Population Amount.Per.Capita  \
# 0     City of Imperial Beach|2022         NaN            $0.00
# 1     City of Imperial Beach|2021         NaN            $0.00
# 2     City of Imperial Beach|2020         NaN            $0.00
# 3     City of Imperial Beach|2019         NaN            $0.00
# 4     City of Imperial Beach|2018         NaN            $0.00
# ...                           ...         ...               ...
# 2026                          NaN         NaN               NaN
# 2027                          NaN         NaN               NaN
# 2028                          NaN         NaN               NaN
# 2029                          NaN         NaN               NaN
# 2030                          NaN         NaN               NaN
#
#      Amount.Per.PEH  Population.PEH    ExpenditureType
# 0            $0.00              0.0      Other/Unknown
# 1            $0.00              0.0      Other/Unknown
# 2            $0.00             16.0      Other/Unknown
# 3            $0.00             12.0      Other/Unknown
# 4            $0.00              7.0      Other/Unknown
# ...             ...             ...                ...
# 2026            NaN             NaN  Crisis Management
# 2027            NaN             NaN         Prevention
# 2028            NaN             NaN         Prevention
# 2029            NaN             NaN         Prevention
# 2030            NaN             NaN         Prevention
#
# [2031 rows x 23 columns]

# %%
cleanexp['Program'].unique()
# Out:
# array([nan, 'rental assistance', 'homeless services', 'shelter',
#        'motel voucher', 'rapid re housing', 'project h.o.p.e.',
#        'take back the streets', 'work for hope',
#        'housing navigation services', 'railing/fencing improvements',
#        'facility improvement', 'housing assistance', 'outreach',
#        'family reunification program',
#        'general funding for homelessness services',
#        'housing stability services', '211 assistance', 'case management',
#        'flexible funds', 'point in time count',
#        'consulting services homeless', 'communities in action',
#        'legal services solutions for change',
#        'translation homeless plan mtg', 'cdbg consolidated plan consult',
#        'plha plan 7699835', 'homelessness prevention',
#        'bridge to housing program', 'homeshare program',
#        'homelessness educational initiatives',
#        'training/technical assistance', 'restrooms', 'service center',
#        'neighborhood revitalization services', 'employment/benefits',
#        'temporary housing and services', 'food and nutrition',
#        'emergency stabalization and supportive services', 'call center',
#        'safe parking', 'transitional storage', 'opening doors program',
#        'bridge to housing network',
#        'transitional housing and supportive services',
#        'contract sobering services', 'interim housing facility'],
#       dtype=object)

# %%
prog_to_drop = ['point in time count','railing/fencing improvements','facility improvement','training/technical assistance']
cleanexp = cleanexp[~cleanexp['Program'].isin(prog_to_drop)]
cleanexp = cleanexp.dropna(subset=['Program'])
cleanexp
# Out:
#      Unique.ID              Grantor                     Grantee  \
# 8          NaN  City of Chula Vista            SBCS CORPORATION
# 9          NaN  City of Chula Vista            SBCS CORPORATION
# 10         NaN  City of Chula Vista            SBCS CORPORATION
# 11        1068  City of Chula Vista            SBCS CORPORATION
# 12        1067  City of Chula Vista  INTERFAITH SHELTER NETWORK
# ...        ...                  ...                         ...
# 2026      1066  City of Chula Vista             ONE TIME VENDOR
# 2027       NaN  City of Chula Vista                KIKU GARDENS
# 2028       NaN  City of Chula Vista                KIKU GARDENS
# 2029       NaN  City of Chula Vista                KIKU GARDENS
# 2030       NaN  City of Chula Vista                 MARK II, LP
#
#                 Program    Year        Date EndDate       Amount  \
# 8     rental assistance  2017.0  10/23/2017     NaN  $14,142.74
# 9     rental assistance  2017.0  10/23/2017     NaN  $12,931.10
# 10    rental assistance  2017.0  10/23/2017     NaN  $10,285.61
# 11    homeless services  2017.0   11/7/2017     NaN     $276.00
# 12              shelter  2017.0   11/8/2017     NaN   $1,971.50
# ...                 ...     ...         ...     ...          ...
# 2026      motel voucher  2021.0  12/23/2021     NaN     $560.30
# 2027  rental assistance  2021.0  12/28/2021     NaN     $212.00
# 2028  rental assistance  2021.0  12/28/2021     NaN     $212.00
# 2029  rental assistance  2021.0  12/28/2021     NaN     $212.00
# 2030  rental assistance  2021.0  12/28/2021     NaN   $1,668.00
#
#      AmendmentNumber     Funding.Agency  ... Issued Funding.Type Years  \
# 8                NaN                NaN  ...    NaN          NaN   NaN
# 9                NaN                NaN  ...    NaN          NaN   NaN
# 10               NaN                NaN  ...    NaN          NaN   NaN
# 11               NaN                NaN  ...    NaN          NaN   NaN
# 12               NaN                NaN  ...    NaN          NaN   NaN
# ...              ...                ...  ...    ...          ...   ...
# 2026             NaN               CDBG  ...    NaN          NaN   NaN
# 2027             NaN               HOME  ...    NaN          NaN   NaN
# 2028             NaN               HOME  ...    NaN          NaN   NaN
# 2029             NaN               HOME  ...    NaN          NaN   NaN
# 2030             NaN  Housing Authority  ...    NaN          NaN   NaN
#
#      Average.By.Year                 City.Year  Population Amount.Per.Capita  \
# 8                NaN  City of Chula Vista|2017    266427.0            $0.05
# 9                NaN  City of Chula Vista|2017    266427.0            $0.05
# 10               NaN  City of Chula Vista|2017    266427.0            $0.04
# 11               NaN  City of Chula Vista|2017    266427.0            $0.00
# 12               NaN  City of Chula Vista|2017    266427.0            $0.01
# ...              ...                       ...         ...               ...
# 2026             NaN                       NaN         NaN               NaN
# 2027             NaN                       NaN         NaN               NaN
# 2028             NaN                       NaN         NaN               NaN
# 2029             NaN                       NaN         NaN               NaN
# 2030             NaN                       NaN         NaN               NaN
#
#      Amount.Per.PEH  Population.PEH    ExpenditureType
# 8           $38.54            367.0         Prevention
# 9           $35.23            367.0         Prevention
# 10          $28.03            367.0         Prevention
# 11           $0.75            367.0  Crisis Management
# 12           $5.37            367.0  Crisis Management
# ...             ...             ...                ...
# 2026            NaN             NaN  Crisis Management
# 2027            NaN             NaN         Prevention
# 2028            NaN             NaN         Prevention
# 2029            NaN             NaN         Prevention
# 2030            NaN             NaN         Prevention
#
# [1210 rows x 23 columns]

# %%
cleanexp.columns
# Out:
# Index(['Unique.ID', 'Grantor', 'Grantee', 'Program', 'Year', 'Date', 'EndDate',
#        'Amount', 'AmendmentNumber', 'Funding.Agency', 'Funding.Source',
#        'Category', 'Location', 'Issued', 'Funding.Type', 'Years',
#        'Average.By.Year', 'City.Year', 'Population', 'Amount.Per.Capita',
#        'Amount.Per.PEH', 'Population.PEH', 'ExpenditureType'],
#       dtype='object')

# %%
col_to_drop = ['Unique.ID', 'EndDate', 'AmendmentNumber', 'Funding.Agency', 'Funding.Source', 'Category','Location', 'Issued', 'Funding.Type', 'Years','Average.By.Year', 'City.Year', 'Population', 'Amount.Per.Capita','Amount.Per.PEH', 'Population.PEH']
cleanexp = cleanexp.drop(columns=col_to_drop)
cleanexp
# Out:
#                   Grantor                     Grantee            Program  \
# 8     City of Chula Vista            SBCS CORPORATION  rental assistance
# 9     City of Chula Vista            SBCS CORPORATION  rental assistance
# 10    City of Chula Vista            SBCS CORPORATION  rental assistance
# 11    City of Chula Vista            SBCS CORPORATION  homeless services
# 12    City of Chula Vista  INTERFAITH SHELTER NETWORK            shelter
# ...                   ...                         ...                ...
# 2026  City of Chula Vista             ONE TIME VENDOR      motel voucher
# 2027  City of Chula Vista                KIKU GARDENS  rental assistance
# 2028  City of Chula Vista                KIKU GARDENS  rental assistance
# 2029  City of Chula Vista                KIKU GARDENS  rental assistance
# 2030  City of Chula Vista                 MARK II, LP  rental assistance
#
#         Year        Date       Amount    ExpenditureType
# 8     2017.0  10/23/2017  $14,142.74          Prevention
# 9     2017.0  10/23/2017  $12,931.10          Prevention
# 10    2017.0  10/23/2017  $10,285.61          Prevention
# 11    2017.0   11/7/2017     $276.00   Crisis Management
# 12    2017.0   11/8/2017   $1,971.50   Crisis Management
# ...      ...         ...          ...                ...
# 2026  2021.0  12/23/2021     $560.30   Crisis Management
# 2027  2021.0  12/28/2021     $212.00          Prevention
# 2028  2021.0  12/28/2021     $212.00          Prevention
# 2029  2021.0  12/28/2021     $212.00          Prevention
# 2030  2021.0  12/28/2021   $1,668.00          Prevention
#
# [1210 rows x 7 columns]

# %%
cleanexp['Program'].unique()
# Out:
# array(['rental assistance', 'homeless services', 'shelter',
#        'motel voucher', 'rapid re housing', 'project h.o.p.e.',
#        'take back the streets', 'work for hope',
#        'housing navigation services', 'housing assistance', 'outreach',
#        'family reunification program',
#        'general funding for homelessness services',
#        'housing stability services', '211 assistance', 'case management',
#        'flexible funds', 'consulting services homeless',
#        'communities in action', 'legal services solutions for change',
#        'translation homeless plan mtg', 'cdbg consolidated plan consult',
#        'plha plan 7699835', 'homelessness prevention',
#        'bridge to housing program', 'homeshare program',
#        'homelessness educational initiatives', 'restrooms',
#        'service center', 'neighborhood revitalization services',
#        'employment/benefits', 'temporary housing and services',
#        'food and nutrition',
#        'emergency stabalization and supportive services', 'call center',
#        'safe parking', 'transitional storage', 'opening doors program',
#        'bridge to housing network',
#        'transitional housing and supportive services',
#        'contract sobering services', 'interim housing facility'],
#       dtype=object)

# %%
consolidation_map = {
    'flexible funds': ['general funding for homelessness services', 'flexible funds'],
    'transitional housing': ['temporary housing and services', 'transitional storage', 'transitional housing and supportive services', 'interim housing facility'],
    'emergency shelter': ['shelter', 'emergency stabilization and supportive services'],
    'staff and operations': ['211 assistance', 'case management', 'translation homeless plan mtg', 'cdbg consolidated plan consult', 'call center', 'employment/benefits']
}

cleanexp['Program'] = cleanexp['Program'].replace('emergency stabalization and supportive services', 'emergency shelter')

def consolidate_program(program):
    for consolidated_name, keywords in consolidation_map.items():
        if any(keyword in program.lower() for keyword in keywords):
            return consolidated_name
    return program  # Return original if no match

cleanexp['Program'] = cleanexp['Program'].apply(consolidate_program)
cleanexp['Program'].unique()
# Out:
# array(['rental assistance', 'homeless services', 'emergency shelter',
#        'motel voucher', 'rapid re housing', 'project h.o.p.e.',
#        'take back the streets', 'work for hope',
#        'housing navigation services', 'housing assistance', 'outreach',
#        'family reunification program', 'flexible funds',
#        'housing stability services', 'staff and operations',
#        'consulting services homeless', 'communities in action',
#        'legal services solutions for change', 'plha plan 7699835',
#        'homelessness prevention', 'bridge to housing program',
#        'homeshare program', 'homelessness educational initiatives',
#        'restrooms', 'service center',
#        'neighborhood revitalization services', 'transitional housing',
#        'food and nutrition', 'safe parking', 'opening doors program',
#        'bridge to housing network', 'contract sobering services'],
#       dtype=object)

# %%
PIT = pd.read_csv('data/raw/PITCount.csv')
PIT
# Out:
#             City  Year  Total PEH  Unsheltered PEH  Population  \
# 0       Carlsbad  2015         88               21      112662
# 1    Chula Vista  2015        498              321      264206
# 2       El Cajon  2015        711              191      103230
# 3      Encinitas  2015        123               80       62590
# 4      Escondido  2015        430              112      150683
# ..           ...   ...        ...              ...         ...
# 135        Poway  2024          1                1       47377
# 136    San Diego  2024       6783             3489     1375452
# 137   San Marcos  2024         35               35       94808
# 138       Santee  2024         73               73       58150
# 139        Vista  2024        271              170       97142
#
#      PEH Per 100,000  Unsheltered Per 100,000   Latitude   Longitude
# 0          78.109744                18.639825  33.158092 -117.350594
# 1         188.489285               121.496105  32.639954 -117.106705
# 2         688.753269               185.023733  32.794773 -116.962524
# 3         196.517016               127.815945  33.039139 -117.295425
# 4         285.367294                74.328225  33.124722 -117.080833
# ..               ...                      ...        ...         ...
# 135         2.110729                 2.110729  32.969895 -117.038479
# 136       493.146980               253.662069  32.715736 -117.161087
# 137        36.916716                36.916716  33.138500 -117.168800
# 138       125.537403               125.537403  32.838383 -116.973915
# 139       278.973050               175.001544  33.193611 -117.241112
#
# [140 rows x 9 columns]

# %%
cleanexp = cleanexp.rename(columns={
    'Grantor': 'City',
    'Grantee': 'Grantee',
    'Program': 'Program',
    'Year': 'Year',
    'Date': 'Date',
    'Amount': 'Amount',
    'ExpenditureType': 'ExpenditureType'
})

# %%
cleanexp['City'] = cleanexp['City'].str.replace('City of ', '')
cleanexp
# Out:
#              City                     Grantee            Program    Year  \
# 8     Chula Vista            SBCS CORPORATION  rental assistance  2017.0
# 9     Chula Vista            SBCS CORPORATION  rental assistance  2017.0
# 10    Chula Vista            SBCS CORPORATION  rental assistance  2017.0
# 11    Chula Vista            SBCS CORPORATION  homeless services  2017.0
# 12    Chula Vista  INTERFAITH SHELTER NETWORK  emergency shelter  2017.0
# ...           ...                         ...                ...     ...
# 2026  Chula Vista             ONE TIME VENDOR      motel voucher  2021.0
# 2027  Chula Vista                KIKU GARDENS  rental assistance  2021.0
# 2028  Chula Vista                KIKU GARDENS  rental assistance  2021.0
# 2029  Chula Vista                KIKU GARDENS  rental assistance  2021.0
# 2030  Chula Vista                 MARK II, LP  rental assistance  2021.0
#
#             Date       Amount    ExpenditureType
# 8     10/23/2017  $14,142.74          Prevention
# 9     10/23/2017  $12,931.10          Prevention
# 10    10/23/2017  $10,285.61          Prevention
# 11     11/7/2017     $276.00   Crisis Management
# 12     11/8/2017   $1,971.50   Crisis Management
# ...          ...          ...                ...
# 2026  12/23/2021     $560.30   Crisis Management
# 2027  12/28/2021     $212.00          Prevention
# 2028  12/28/2021     $212.00          Prevention
# 2029  12/28/2021     $212.00          Prevention
# 2030  12/28/2021   $1,668.00          Prevention
#
# [1210 rows x 7 columns]

# %%
cleanexp = cleanexp[~cleanexp['Year'].isna()]
cleanexp['Year'] = cleanexp['Year'].astype(int)
cleanexp
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_54396\708859221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleanexp['Year'] = cleanexp['Year'].astype(int)
#              City                     Grantee            Program  Year  \
# 8     Chula Vista            SBCS CORPORATION  rental assistance  2017
# 9     Chula Vista            SBCS CORPORATION  rental assistance  2017
# 10    Chula Vista            SBCS CORPORATION  rental assistance  2017
# 11    Chula Vista            SBCS CORPORATION  homeless services  2017
# 12    Chula Vista  INTERFAITH SHELTER NETWORK  emergency shelter  2017
# ...           ...                         ...                ...   ...
# 2026  Chula Vista             ONE TIME VENDOR      motel voucher  2021
# 2027  Chula Vista                KIKU GARDENS  rental assistance  2021
# 2028  Chula Vista                KIKU GARDENS  rental assistance  2021
# 2029  Chula Vista                KIKU GARDENS  rental assistance  2021
# 2030  Chula Vista                 MARK II, LP  rental assistance  2021
#
#             Date       Amount    ExpenditureType
# 8     10/23/2017  $14,142.74          Prevention
# 9     10/23/2017  $12,931.10          Prevention
# 10    10/23/2017  $10,285.61          Prevention
# 11     11/7/2017     $276.00   Crisis Management
# 12     11/8/2017   $1,971.50   Crisis Management
# ...          ...          ...                ...
# 2026  12/23/2021     $560.30   Crisis Management
# 2027  12/28/2021     $212.00          Prevention
# 2028  12/28/2021     $212.00          Prevention
# 2029  12/28/2021     $212.00          Prevention
# 2030  12/28/2021   $1,668.00          Prevention
#
# [808 rows x 7 columns]

# %%
cleanexp['City'] = cleanexp['City'].replace('SDHC', 'San Diego')
PIT['Year'] -= 1
df = pd.merge(PIT, cleanexp, on=['City', 'Year'], how='inner')
df
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_54396\2310359685.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleanexp['City'] = cleanexp['City'].replace('SDHC', 'San Diego')
#            City  Year  Total PEH  Unsheltered PEH  Population  \
# 0      El Cajon  2014        711              191      103230
# 1      El Cajon  2014        711              191      103230
# 2      El Cajon  2015        321              218      103527
# 3      El Cajon  2015        321              218      103527
# 4    San Marcos  2015         99               44       94932
# ..          ...   ...        ...              ...         ...
# 595   San Diego  2022       6500             3285     1378307
# 596  San Marcos  2022          2                2       94832
# 597  San Marcos  2022          2                2       94832
# 598  San Marcos  2022          2                2       94832
# 599    Coronado  2023          0                0       19268
#
#      PEH Per 100,000  Unsheltered Per 100,000   Latitude   Longitude  \
# 0         688.753269               185.023733  32.794773 -116.962524
# 1         688.753269               185.023733  32.794773 -116.962524
# 2         310.064041               210.573087  32.794773 -116.962524
# 3         310.064041               210.573087  32.794773 -116.962524
# 4         104.285173                46.348966  33.138500 -117.168800
# ..               ...                      ...        ...         ...
# 595       471.593049               238.335871  32.715736 -117.161087
# 596         2.108993                 2.108993  33.138500 -117.168800
# 597         2.108993                 2.108993  33.138500 -117.168800
# 598         2.108993                 2.108993  33.138500 -117.168800
# 599         0.000000                 0.000000  32.631718 -117.136772
#
#                                     Grantee               Program      Date  \
# 0    East County Transitional Living Center     emergency shelter  7/1/2013
# 1    East County Transitional Living Center     emergency shelter  7/1/2013
# 2    East County Transitional Living Center     emergency shelter  7/1/2014
# 3    East County Transitional Living Center     emergency shelter  7/1/2014
# 4                     North County Lifeline    housing assistance       NaN
# ..                                      ...                   ...       ...
# 595                     Father Joes Village     emergency shelter  7/1/2022
# 596         Alliance for Regional Solutions     emergency shelter       NaN
# 597                           211 San Diego  staff and operations       NaN
# 598                    Solutions for Change        flexible funds       NaN
# 599             St. Vincent de Paul Village  transitional housing  5/1/2023
#
#            Amount    ExpenditureType
# 0     $75,000.00   Crisis Management
# 1     $75,000.00   Crisis Management
# 2    $120,000.00   Crisis Management
# 3    $120,000.00   Crisis Management
# 4           21600         Prevention
# ..            ...                ...
# 595  $572,900.00   Crisis Management
# 596        125000  Crisis Management
# 597         56792  Crisis Management
# 598         21347  Crisis Management
# 599      95680.33  Crisis Management
#
# [600 rows x 14 columns]

# %%
df = df.drop(columns= ['Latitude', 'Longitude', 'Date'])
df['Amount'] = df['Amount'].str.replace('$', '', regex=False)
df['Amount'] = df['Amount'].str.replace(',', '',regex=False)
df
# Out:
#            City  Year  Total PEH  Unsheltered PEH  Population  \
# 0      El Cajon  2014        711              191      103230
# 1      El Cajon  2014        711              191      103230
# 2      El Cajon  2015        321              218      103527
# 3      El Cajon  2015        321              218      103527
# 4    San Marcos  2015         99               44       94932
# ..          ...   ...        ...              ...         ...
# 595   San Diego  2022       6500             3285     1378307
# 596  San Marcos  2022          2                2       94832
# 597  San Marcos  2022          2                2       94832
# 598  San Marcos  2022          2                2       94832
# 599    Coronado  2023          0                0       19268
#
#      PEH Per 100,000  Unsheltered Per 100,000  \
# 0         688.753269               185.023733
# 1         688.753269               185.023733
# 2         310.064041               210.573087
# 3         310.064041               210.573087
# 4         104.285173                46.348966
# ..               ...                      ...
# 595       471.593049               238.335871
# 596         2.108993                 2.108993
# 597         2.108993                 2.108993
# 598         2.108993                 2.108993
# 599         0.000000                 0.000000
#
#                                     Grantee               Program      Amount  \
# 0    East County Transitional Living Center     emergency shelter   75000.00
# 1    East County Transitional Living Center     emergency shelter   75000.00
# 2    East County Transitional Living Center     emergency shelter  120000.00
# 3    East County Transitional Living Center     emergency shelter  120000.00
# 4                     North County Lifeline    housing assistance       21600
# ..                                      ...                   ...         ...
# 595                     Father Joes Village     emergency shelter  572900.00
# 596         Alliance for Regional Solutions     emergency shelter      125000
# 597                           211 San Diego  staff and operations       56792
# 598                    Solutions for Change        flexible funds       21347
# 599             St. Vincent de Paul Village  transitional housing    95680.33
#
#        ExpenditureType
# 0    Crisis Management
# 1    Crisis Management
# 2    Crisis Management
# 3    Crisis Management
# 4           Prevention
# ..                 ...
# 595  Crisis Management
# 596  Crisis Management
# 597  Crisis Management
# 598  Crisis Management
# 599  Crisis Management
#
# [600 rows x 11 columns]

# %%
df['Year'] = df['Year'].replace(0, np.nan)
df = df.dropna()


df.to_csv('data/processed/expenditures_and_PIT.csv', index=False)
